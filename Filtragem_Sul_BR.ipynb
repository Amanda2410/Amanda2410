# %% [markdown]
# <a href="https://colab.research.google.com/github/Amanda2410/Amanda2410/blob/main/Filtragem_Sul_BR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importando a biblioteca pandas
import pandas as pd

# Carregando a planilha CSV
# Usamos o separador ';' pois é comum em arquivos brasileiros
# encoding='latin1' para evitar erro com acentos
df = pd.read_csv('/content/datatran2024.csv', sep=';', encoding='latin1')  # Obs:/content/ é a pasta padrão do Google Colab, onde os arquivos enviados e salvos ficam


# Limpeza dos dados
# Converter a coluna de data para o formato datetime
df['data_inversa'] = pd.to_datetime(df['data_inversa'], format='%Y-%m-%d', errors='coerce')
# Criar uma nova coluna com o número do mês
df['mes'] = df['data_inversa'].dt.month

# Definindo colunas essenciais que não podem estar vazias
colunas_essenciais = [
    'data_inversa', 'uf', 'municipio',
    'causa_acidente', 'tipo_acidente',
    'classificacao_acidente'
]
# Removendo linhas que têm valores ausentes nessas colunas
df = df.dropna(subset=colunas_essenciais)

# Passo 3: Filtrar apenas os estados do Sul
ufs_sul = ['PR', 'SC', 'RS']
df_sul = df[df['uf'].isin(ufs_sul)]

# Exportando para novo arquivo csv
df_sul.to_csv('/content/acidentes_sul_2024.csv', index=False, sep=';', encoding='latin1')

# Visualizar os primeiros registros
df_sul.head()
# Out:
#           id data_inversa     dia_semana   horario  uf   br     km  \
# 11  571976.0   2024-01-01  segunda-feira  15:00:00  PR  376    327
# 15  572015.0   2024-01-01  segunda-feira  22:30:00  RS  101     22
# 30  572088.0   2024-01-02    terça-feira  09:15:00  RS  470   53,7
# 36  572175.0   2024-01-02    terça-feira  15:20:00  RS  386    250
# 37  572178.0   2024-01-02    terça-feira  11:50:00  SC  282  376,6
#
#           municipio                                     causa_acidente  \
# 11       ORTIGUEIRA           Reação tardia ou ineficiente do condutor
# 15  TRES CACHOEIRAS                     Ausência de reação do condutor
# 30   LAGOA VERMELHA                     Ausência de reação do condutor
# 36         SOLEDADE           Reação tardia ou ineficiente do condutor
# 37    HERVAL DOESTE  Falta de elemento de contenção que evite a saí...
#
#                     tipo_acidente  ... ilesos ignorados feridos veiculos  \
# 11                     Tombamento  ...      1         1       1        2
# 15  Colisão lateral mesmo sentido  ...      3         2       0        4
# 30                     Tombamento  ...      0         2       1        3
# 36          Derramamento de carga  ...      1         1       0        2
# 37      Saída de leito carroçável  ...      0         0       1        1
#
#      latitude  longitude regional  delegacia             uop  mes
# 11 -24.065934 -51.064322  SPRF-PR   DEL07-PR  UOP02-DEL07-PR    1
# 15 -29.439807 -49.901139  SPRF-RS   DEL03-RS  UOP02-DEL03-RS    1
# 30 -28.203287 -51.525436  SPRF-RS   DEL08-RS  UOP05-DEL08-RS    1
# 36 -28.826591 -52.468510  SPRF-RS   DEL04-RS  UOP03-DEL04-RS    1
# 37 -27.220205 -51.461185  SPRF-SC   DEL07-SC  UOP05-DEL07-SC    1
#
# [5 rows x 31 columns]
